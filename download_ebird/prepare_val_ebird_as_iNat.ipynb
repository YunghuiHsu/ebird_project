# %% [markdown]
# #### 與iNaturalist 資料比對的Ebird驗證資料集
# - 按照iNaturalist 物種名錄(num_sp=1486)
#     - 每種最多選10張

# %%
import sys 
import os
import pandas as pd
import numpy as np
from pathlib import Path 
from PIL import Image
import shutil
import time
import datetime


print(pd.__version__)
print(np.__version__)
# !python -V
# !pwd

dir_meta = Path('meta')
dir_meta.mkdir(exist_ok=True, parents=True)
# Out:
# 1.4.1
# 1.22.2
# Python 3.9.7
# /home/esslab/AI_projects/shared/eBird/download_ebird

# %% [markdown]
# ## work pipiline
# 1. 根據iNaturalist 2021 dayaset取得鳥類物種名錄與流水號
# 2. 產出`ebird_1486_selected/val` 目錄
# 3. 根據物種名，至ebird meta 資料取得對應得物種名
# 4. 依據該物種名索引，參照`Average Community Rating`與`Number of Ratings`取top10
# 5. 照檔案路徑取得資料後複製到所屬的資料夾

# %% [markdown]
# ### 1. 根據iNaturalist 2021 dayaset取得鳥類物種名錄與流水號

# %%
# !ls downloaded/ebird_1486_sel/val -l

# %%
dir_iNat = Path('../../../shared/iNaturalist_2021') 
iNat_val = dir_iNat/'val'
dir_name_iNatVal  = [dir_.name for dir_ in iNat_val.iterdir()] 
print(len(dir_name_iNatVal))

# get Specie & Family list 
sp_list = [file.split('_')[-2] + ' ' + file.split('_')[-1]  
           for file in dir_name_iNatVal]

family_list = [file.split('_')[-3] for file in dir_name_iNatVal]

df_iNat_val =  pd.concat([pd.DataFrame(dir_name_iNatVal),
                          pd.DataFrame(family_list),
                          pd.DataFrame(sp_list)],
              axis='columns').set_axis(['Dir','Family','Specie'],axis='columns')
df_iNat_val
# Out:
# 1486
#                                                     Dir         Family  \
# 0     03908_Animalia_Chordata_Aves_Passeriformes_Lan...       Laniidae
# 1     04326_Animalia_Chordata_Aves_Passeriformes_Tyr...     Tyrannidae
# 2     04026_Animalia_Chordata_Aves_Passeriformes_Par...        Paridae
# 3     03284_Animalia_Chordata_Aves_Bucerotiformes_Ph...  Phoeniculidae
# 4     03111_Animalia_Chordata_Aves_Accipitriformes_A...   Accipitridae
# ...                                                 ...            ...
# 1481  03388_Animalia_Chordata_Aves_Charadriiformes_J...      Jacanidae
# 1482  03859_Animalia_Chordata_Aves_Passeriformes_Hir...   Hirundinidae
# 1483  03362_Animalia_Chordata_Aves_Charadriiformes_C...   Charadriidae
# 1484  04556_Animalia_Chordata_Aves_Strigiformes_Stri...      Strigidae
# 1485  03557_Animalia_Chordata_Aves_Coraciiformes_Alc...    Alcedinidae
#
#                         Specie
# 0              Lanius collurio
# 1         Todirostrum cinereum
# 2     Baeolophus atricristatus
# 3        Phoeniculus purpureus
# 4             Accipiter badius
# ...                        ...
# 1481  Hydrophasianus chirurgus
# 1482           Riparia riparia
# 1483    Charadrius tricollaris
# 1484     Ninox novaeseelandiae
# 1485         Megaceryle alcyon
#
# [1486 rows x 3 columns]

# %% [markdown]
# ### 2. 產出ebird_1486_selected/val 目錄
# - 物種目錄參照iNaturalist

# %%
# mkdir ebird_1486_selected/val
ebird_val = dir_iNat/'val_ebird'

for dir_ in  dir_name_iNatVal:
    dir_ = ebird_val/dir_
    dir_.mkdir(exist_ok=True, parents=True)
    print(f'{dir_} maked')

# %% [markdown]
# ### 3. 根據物種名，至ebird meta 資料取得對應得物種名

# %% [markdown]
# #### load ebird meta

# %%
# %%time
meta_file = dir_meta/'jpg_top100_meta3.csv'
df_jpg100_meta = pd.read_csv(meta_file, index_col=0, 
                            #  dtype=column_dtypes
                             )
df_jpg100_meta.info()
# Out:
# <timed exec>:2: DtypeWarning: Columns (31,32,33,60) have mixed types. Specify dtype option on import or set low_memory=False.
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 896555 entries, 0 to 896554
# Data columns (total 62 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   ML Catalog Number            896555 non-null  int64
#  1   Dir_FName                    896555 non-null  object
#  2   Parent_Dir                   896555 non-null  object
#  3   Size                         896555 non-null  float64
#  4   Sci_N                        896555 non-null  object
#  5   Macaulay_public              37 non-null      float64
#  6   Format                       896521 non-null  object
#  7   Scientific Name              896535 non-null  object
#  8   Common Name                  896521 non-null  object
#  9   Background Species           1807 non-null    object
#  10  Recordist                    896478 non-null  object
#  11  Date                         884239 non-null  object
#  12  Year                         884239 non-null  float64
#  13  Month                        884239 non-null  float64
#  14  Day                          884239 non-null  float64
#  15  Time                         884090 non-null  float64
#  16  Country                      896322 non-null  object
#  17  Country-State-County         896322 non-null  object
#  18  State                        896322 non-null  object
#  19  County                       321560 non-null  object
#  20  Locality                     886633 non-null  object
#  21  Latitude                     886648 non-null  float64
#  22  Longitude                    886648 non-null  float64
#  23  Elevation (m)                0 non-null       float64
#  24  Age/Sex                      701832 non-null  object
#  25  Behaviors                    38113 non-null   object
#  26  Playback                     896521 non-null  object
#  27  Collected                    0 non-null       float64
#  28  Specimen ID                  0 non-null       float64
#  29  Home Archive Catalog Number  91282 non-null   object
#  30  Recorder                     9 non-null       object
#  31  Microphone                   7 non-null       object
#  32  Accessory                    2 non-null       object
#  33  Partner Institution          0 non-null       float64
#  34  eBird Checklist ID           884090 non-null  object
#  35  Unconfirmed?                 0 non-null       float64
#  36  Air Temp(ºC)                 0 non-null       float64
#  37  Water Temp(ºC)               0 non-null       float64
#  38  Media notes                  124591 non-null  object
#  39  Observation Details          223389 non-null  object
#  40  Class                        0 non-null       float64
#  41  Order                        0 non-null       float64
#  42  Family                       896518 non-null  object
#  43  Parent Species               896508 non-null  object
#  44  eBird Species Code           896521 non-null  object
#  45  Taxon Category               896521 non-null  object
#  46  Taxonomic Sort               896521 non-null  float64
#  47  Recordist 2 Display Name     0 non-null       float64
#  48  Recordist 2 Profile URL      0 non-null       float64
#  49  Average Community Rating     896517 non-null  float64
#  50  Number of Ratings            896521 non-null  float64
#  51  Asset State                  896521 non-null  object
#  52  Asset Tags                   26053 non-null   object
#  53  Contributor Profile URL      732662 non-null  object
#  54  Original Image Height        879330 non-null  float64
#  55  Original Image Width         879330 non-null  float64
#  56  Specimen Page URL            896521 non-null  object
#  57  eBird Checklist URL          884090 non-null  object
#  58  ebird Species URL            863876 non-null  object
#  59  isInternalUser               896521 non-null  object
#  60  mediaDownloadUrl             896521 non-null  object
#  61  report_as                    896521 non-null  object
# dtypes: float64(24), int64(1), object(37)
# memory usage: 430.9+ MB
# CPU times: user 11.6 s, sys: 12.5 s, total: 24.1 s
# Wall time: 24.1 s

# %%
col_basic =  ['ML Catalog Number','Dir_FName', 'Parent_Dir', 'Sci_N',]
# col_geo = ['County', 'Locality', 'Latitude','Longitude']
col_taxon = ['Scientific Name',  'Parent Species', 'Taxon Category']
col_rating = ['Number of Ratings', 'Average Community Rating',]

# %%
df_jpg100_meta_sel = df_jpg100_meta[col_basic + col_taxon + col_rating]
df_jpg100_meta_sel
# Out:
#         ML Catalog Number                                         Dir_FName  \
# 0               114289801  Acanthisittidae/Acanthisitta_chloris_0_114289801
# 1               114289821  Acanthisittidae/Acanthisitta_chloris_0_114289821
# 2               114404941  Acanthisittidae/Acanthisitta_chloris_0_114404941
# 3               114404951  Acanthisittidae/Acanthisitta_chloris_0_114404951
# 4               115495451  Acanthisittidae/Acanthisitta_chloris_0_115495451
# ...                   ...                                               ...
# 896550           59630711    Zosteropidae/Zosterornis_whiteheadi_0_59630711
# 896551           59630721    Zosteropidae/Zosterornis_whiteheadi_0_59630721
# 896552           63554951    Zosteropidae/Zosterornis_whiteheadi_0_63554951
# 896553           79738531    Zosteropidae/Zosterornis_whiteheadi_0_79738531
# 896554           79738541    Zosteropidae/Zosterornis_whiteheadi_0_79738541
#
#              Parent_Dir                     Sci_N         Scientific Name  \
# 0       Acanthisittidae    Acanthisitta_chloris_0    Acanthisitta chloris
# 1       Acanthisittidae    Acanthisitta_chloris_0    Acanthisitta chloris
# 2       Acanthisittidae    Acanthisitta_chloris_0    Acanthisitta chloris
# 3       Acanthisittidae    Acanthisitta_chloris_0    Acanthisitta chloris
# 4       Acanthisittidae    Acanthisitta_chloris_0    Acanthisitta chloris
# ...                 ...                       ...                     ...
# 896550     Zosteropidae  Zosterornis_whiteheadi_0  Zosterornis whiteheadi
# 896551     Zosteropidae  Zosterornis_whiteheadi_0  Zosterornis whiteheadi
# 896552     Zosteropidae  Zosterornis_whiteheadi_0  Zosterornis whiteheadi
# 896553     Zosteropidae  Zosterornis_whiteheadi_0  Zosterornis whiteheadi
# 896554     Zosteropidae  Zosterornis_whiteheadi_0  Zosterornis whiteheadi
#
#                 Parent Species Taxon Category  Number of Ratings  \
# 0         Acanthisitta chloris        Species                2.0
# 1         Acanthisitta chloris        Species                2.0
# 2         Acanthisitta chloris        Species                2.0
# 3         Acanthisitta chloris        Species                2.0
# 4         Acanthisitta chloris        Species               21.0
# ...                        ...            ...                ...
# 896550  Zosterornis whiteheadi        Species                1.0
# 896551  Zosterornis whiteheadi        Species                0.0
# 896552  Zosterornis whiteheadi        Species                1.0
# 896553  Zosterornis whiteheadi        Species                4.0
# 896554  Zosterornis whiteheadi        Species                4.0
#
#         Average Community Rating
# 0                          4.000
# 1                          4.000
# 2                          4.500
# 3                          4.000
# 4                          4.906
# ...                          ...
# 896550                     3.000
# 896551                     0.000
# 896552                     3.000
# 896553                     3.000
# 896554                     2.750
#
# [896555 rows x 9 columns]

# %% [markdown]
# #### checking sp list

# %%
sp_iNat =  df_iNat_val.Specie.unique()

sp_ebird = df_jpg100_meta_sel['Parent Species'].unique()

set_diff =  set(sp_iNat) - set(sp_ebird)
print(f'#_sp in iNat  : {len(sp_iNat)}')
print(f'#_sp in ebird : {len(sp_ebird)}')
print(f'#_sp_lack in ebird : {len(set_diff):,d}, {set_diff}') 

assert len(set_diff)==0
# Out:
# #_sp in iNat  : 1486
# #_sp in ebird : 11215
# #_sp_lack in ebird : 0, set()

# %% [markdown]
# ### 4. 依據該物種名索引取得檔案路徑
# - 參照`Average Community Rating`與`Number of Ratings`取top10

# %%
# sp_ = 'Lanius collurio' # 'Accipiter badius'
sp_ = 'Hydrophasianus chirurgus'

def get_path(df_:pd.DataFrame, sp_:str)->tuple:
    mask = df_['Parent Species'] == sp_
    df_ = (df_[mask]
           .sort_values(by=col_rating, ascending=False)
           .head(10))
    
    return df_['Dir_FName'].values
    # return df_ 

# print(sp_)
paths = get_path(df_jpg100_meta_sel, sp_)
paths
# Out:
# array(['Jacanidae/Hydrophasianus_chirurgus_0_714944',
#        'Jacanidae/Hydrophasianus_chirurgus_0_205014781',
#        'Jacanidae/Hydrophasianus_chirurgus_0_206055751',
#        'Jacanidae/Hydrophasianus_chirurgus_0_205593231',
#        'Jacanidae/Hydrophasianus_chirurgus_0_108262961',
#        'Jacanidae/Hydrophasianus_chirurgus_0_115911651',
#        'Jacanidae/Hydrophasianus_chirurgus_0_126261371',
#        'Jacanidae/Hydrophasianus_chirurgus_0_139014661',
#        'Jacanidae/Hydrophasianus_chirurgus_0_243700561',
#        'Jacanidae/Hydrophasianus_chirurgus_0_26123191'], dtype=object)

# %% [markdown]
# ### 5. 照檔案路徑取得資料後複製到所屬的資料夾

# %%
dir_ebird = Path('downloaded/jpg_top100')

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
encoder.to(device)

start_time = time.time()
for i, (images, *_) in enumerate(data_loader):
    images = images.to(device)
    
    with torch.no_grad():
        embedding_ = encoder.forward_features(images)
        # embedding_ = embedding_.detach().cpu().numpy()

    if i == 0 :
        embeddings = embedding_
    else:
        embeddings = torch.cat((embeddings, embedding_), axis=0)    
    
    passing_time = str(datetime.timedelta(seconds=int(time.time() - start_time )))
    info = f'Progress:{i+1:4d}, {100*(i+1)/len(data_loader):3.2f}%. ' 
    info += f'| Feature_shape: {embeddings.shape}.' 
    info += f'| Time: {passing_time}. '
    print(info, end='\r')

# %%
start_time = time.time()
for idx, rows in df_iNat_val.iterrows():
    dir_, family_, sp_ = rows
    
    paths = get_path(df_jpg100_meta_sel, sp_)
    for idx_p, path in enumerate(paths):
        src = dir_ebird.joinpath(path  + '.jpg')
        dst = ebird_val.joinpath(dir_, Path(path).name + '.jpg')
        shutil.copyfile(src, dst)
        # print(f'\t{idx_p:2d}, Copy imgs : {Path(path).name}')
    
    passing_time = str(datetime.timedelta(seconds=int(time.time() - start_time )))
    # print(f'{idx:4d}, {family_:10s}, {sp_:15s}, data dst : {dir_}')
    info = f'Progress : {idx:4d}, Time: {passing_time} '
    info += f'| Taxon: {family_:15s}, {sp_:25s}, n:{len(paths)}  '
    info += f'| Data dst : {dir_:<40s}'
    print(info, end='\r')
    # break
# Out:
# Progress : 1485, Time: 0:01:20 | Taxon: Alcedinidae    , Megaceryle alcyon        , n:10  | Data dst : 03557_Animalia_Chordata_Aves_Coraciiformes_Alcedinidae_Megaceryle_alcyoneollaristelisrissisuss

# %% [markdown]
# ## 建立 meta data
# －'AI_projects/shared/iNaturalist_2021/meta ebird_val.csv'

# %%
# %%time
meta_file =  'meta/jpg_top100_meta4.csv'
df_jpg100_meta =pd.read_csv(meta_file, index_col=0)
df_jpg100_meta
# Out:
# <timed exec>:2: DtypeWarning: Columns (10,31,32,33,60) have mixed types. Specify dtype option on import or set low_memory=False.
# CPU times: user 6.8 s, sys: 1.33 s, total: 8.13 s
# Wall time: 8.14 s
#         ML_Catalog_Number                                         Dir_FName  \
# 0               114289801  Acanthisittidae/Acanthisitta_chloris_0_114289801
# 1               114289821  Acanthisittidae/Acanthisitta_chloris_0_114289821
# 2               114404941  Acanthisittidae/Acanthisitta_chloris_0_114404941
# 3               114404951  Acanthisittidae/Acanthisitta_chloris_0_114404951
# 4               115495451  Acanthisittidae/Acanthisitta_chloris_0_115495451
# ...                   ...                                               ...
# 896550           59630711    Zosteropidae/Zosterornis_whiteheadi_0_59630711
# 896551           59630721    Zosteropidae/Zosterornis_whiteheadi_0_59630721
# 896552           63554951    Zosteropidae/Zosterornis_whiteheadi_0_63554951
# 896553           79738531    Zosteropidae/Zosterornis_whiteheadi_0_79738531
# 896554           79738541    Zosteropidae/Zosterornis_whiteheadi_0_79738541
#
#              Parent_Dir    Size                     Sci_N  Macaulay_public  \
# 0       Acanthisittidae  287.80    Acanthisitta_chloris_0              NaN
# 1       Acanthisittidae  205.43    Acanthisitta_chloris_0              NaN
# 2       Acanthisittidae  335.58    Acanthisitta_chloris_0              NaN
# 3       Acanthisittidae  261.37    Acanthisitta_chloris_0              NaN
# 4       Acanthisittidae   97.31    Acanthisitta_chloris_0              NaN
# ...                 ...     ...                       ...              ...
# 896550     Zosteropidae  211.91  Zosterornis_whiteheadi_0              NaN
# 896551     Zosteropidae  194.77  Zosterornis_whiteheadi_0              NaN
# 896552     Zosteropidae  254.81  Zosterornis_whiteheadi_0              NaN
# 896553     Zosteropidae  251.04  Zosterornis_whiteheadi_0              NaN
# 896554     Zosteropidae  248.19  Zosterornis_whiteheadi_0              NaN
#
#        Format                Sci_Name             Common_Name  \
# 0       Photo    Acanthisitta chloris                Rifleman
# 1       Photo    Acanthisitta chloris                Rifleman
# 2       Photo    Acanthisitta chloris                Rifleman
# 3       Photo    Acanthisitta chloris                Rifleman
# 4       Photo    Acanthisitta chloris                Rifleman
# ...       ...                     ...                     ...
# 896550  Photo  Zosterornis whiteheadi  Chestnut-faced Babbler
# 896551  Photo  Zosterornis whiteheadi  Chestnut-faced Babbler
# 896552  Photo  Zosterornis whiteheadi  Chestnut-faced Babbler
# 896553  Photo  Zosterornis whiteheadi  Chestnut-faced Babbler
# 896554  Photo  Zosterornis whiteheadi  Chestnut-faced Babbler
#
#        Background_Species  ... Original_Image_Height Original_Image_Width  \
# 0                     NaN  ...                2836.0               4120.0
# 1                     NaN  ...                4000.0               6000.0
# 2                     NaN  ...                1665.0               2500.0
# 3                     NaN  ...                1669.0               2500.0
# 4                     NaN  ...                1565.0               2400.0
# ...                   ...  ...                   ...                  ...
# 896550                NaN  ...                1983.0               2976.0
# 896551                NaN  ...                1848.0               2772.0
# 896552                NaN  ...                 841.0               1500.0
# 896553                NaN  ...                 829.0               1500.0
# 896554                NaN  ...                 941.0               1500.0
#
#                                   Specimen_Page_URL  \
# 0       https://macaulaylibrary.org/asset/114289801
# 1       https://macaulaylibrary.org/asset/114289821
# 2       https://macaulaylibrary.org/asset/114404941
# 3       https://macaulaylibrary.org/asset/114404951
# 4       https://macaulaylibrary.org/asset/115495451
# ...                                             ...
# 896550   https://macaulaylibrary.org/asset/59630711
# 896551   https://macaulaylibrary.org/asset/59630721
# 896552   https://macaulaylibrary.org/asset/63554951
# 896553   https://macaulaylibrary.org/asset/79738531
# 896554   https://macaulaylibrary.org/asset/79738541
#
#                                eBird_Checklist_URL  \
# 0       https://ebird.org/view/checklist/S26591349
# 1       https://ebird.org/view/checklist/S26591349
# 2       https://ebird.org/view/checklist/S48312775
# 3       https://ebird.org/view/checklist/S48312775
# 4       https://ebird.org/view/checklist/S48500276
# ...                                            ...
# 896550  https://ebird.org/view/checklist/S35659495
# 896551  https://ebird.org/view/checklist/S35659495
# 896552  https://ebird.org/view/checklist/S38159117
# 896553  https://ebird.org/view/checklist/S41419807
# 896554  https://ebird.org/view/checklist/S41419807
#
#                         ebird_Species_URL  isInternalUser  \
# 0       https://ebird.org/species/riflem1           False
# 1       https://ebird.org/species/riflem1           False
# 2       https://ebird.org/species/riflem1           False
# 3       https://ebird.org/species/riflem1           False
# 4       https://ebird.org/species/riflem1           False
# ...                                   ...             ...
# 896550  https://ebird.org/species/chfbab1           False
# 896551  https://ebird.org/species/chfbab1           False
# 896552  https://ebird.org/species/chfbab1           False
# 896553  https://ebird.org/species/chfbab1           False
# 896554  https://ebird.org/species/chfbab1           False
#
#                                          mediaDownloadUrl report_as  \
# 0       https://cdn.download.ams.birds.cornell.edu/api...   riflem1
# 1       https://cdn.download.ams.birds.cornell.edu/api...   riflem1
# 2       https://cdn.download.ams.birds.cornell.edu/api...   riflem1
# 3       https://cdn.download.ams.birds.cornell.edu/api...   riflem1
# 4       https://cdn.download.ams.birds.cornell.edu/api...   riflem1
# ...                                                   ...       ...
# 896550  https://cdn.download.ams.birds.cornell.edu/api...   chfbab1
# 896551  https://cdn.download.ams.birds.cornell.edu/api...   chfbab1
# 896552  https://cdn.download.ams.birds.cornell.edu/api...   chfbab1
# 896553  https://cdn.download.ams.birds.cornell.edu/api...   chfbab1
# 896554  https://cdn.download.ams.birds.cornell.edu/api...   chfbab1
#
#                Genus           SCI_NAME_2021
# 0       Acanthisitta    Acanthisitta chloris
# 1       Acanthisitta    Acanthisitta chloris
# 2       Acanthisitta    Acanthisitta chloris
# 3       Acanthisitta    Acanthisitta chloris
# 4       Acanthisitta    Acanthisitta chloris
# ...              ...                     ...
# 896550   Zosterornis  Zosterornis whiteheadi
# 896551   Zosterornis  Zosterornis whiteheadi
# 896552   Zosterornis  Zosterornis whiteheadi
# 896553   Zosterornis  Zosterornis whiteheadi
# 896554   Zosterornis  Zosterornis whiteheadi
#
# [896555 rows x 64 columns]

# %%
df_meta_iNat = pd.read_csv('../../iNaturalist_2021/meta/val.csv', index_col=0)
df_meta_iNat.set_axis(df_meta_iNat.columns.str.capitalize(), axis='columns', inplace=True)
df_meta_iNat.columns
# Out:
# Index(['Id', 'Category_id', 'Width', 'Height', 'File_name', 'License',
#        'Rights_holder', 'Date', 'Latitude', 'Longitude',
#        'Location_uncertainty', 'Name', 'Common_name', 'Supercategory',
#        'Kingdom', 'Phylum', 'Class', 'Order', 'Family', 'Genus',
#        'Specific_epithet', 'Image_dir_name'],
#       dtype='object')

# %%
data_path = '../../iNaturalist_2021'
val_data = 'val_ebird'
    
imgs_path = Path( data_path, val_data)

# !find  {str(imgs_path)} -type f |grep -c jpg
# delete .ipynb files
# !find  {str(imgs_path)} -type f |grep .ipynb  | xargs rm -v  

files_path_ = [f for f in imgs_path.glob('**/*') if f.suffix.lower() in ['.jpg', '.jpeg', '.png']]
files_path_.sort()
# exlude .ipynb files
files_path_ = [f for f in files_path_ if not f.name.startswith('.')] 

files_path_ = [('/').join(f.parts[3:]) for f in files_path_]

print(len(files_path_))
# Out:
# 14860
# rm: missing operand
# Try 'rm --help' for more information.
# 14860

# %%
print(df_meta_iNat.File_name[0])
df_meta_iNat.Image_dir_name[0]
# Out:
# val/03938_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Ptilotula_penicillata/df8edd4c-fbb4-4886-8600-a429e5efac23.jpg
# '03938_Animalia_Chordata_Aves_Passeriformes_Meliphagidae_Ptilotula_penicillata'

# %%
df_meta_iNat.sort_values(by=['Image_dir_name'])
# Out:
#            Id  Category_id  Width  Height  \
# 8854  2742608         3111    500     374
# 8859  2783801         3111    500     500
# 8858  2782750         3111    500     327
# 8857  2776272         3111    500     375
# 8856  2759352         3111    500     369
# ...       ...          ...    ...     ...
# 5621  2695404         4596    500     333
# 5620  2691084         4596    500     375
# 5627  2757534         4596    332     500
# 5628  2758135         4596    500     375
# 5625  2734402         4596    500     351
#
#                                               File_name  License  \
# 8854  val/03111_Animalia_Chordata_Aves_Accipitriform...        1
# 8859  val/03111_Animalia_Chordata_Aves_Accipitriform...        0
# 8858  val/03111_Animalia_Chordata_Aves_Accipitriform...        1
# 8857  val/03111_Animalia_Chordata_Aves_Accipitriform...        1
# 8856  val/03111_Animalia_Chordata_Aves_Accipitriform...        1
# ...                                                 ...      ...
# 5621  val/04596_Animalia_Chordata_Aves_Trogoniformes...        1
# 5620  val/04596_Animalia_Chordata_Aves_Trogoniformes...        0
# 5627  val/04596_Animalia_Chordata_Aves_Trogoniformes...        1
# 5628  val/04596_Animalia_Chordata_Aves_Trogoniformes...        1
# 5625  val/04596_Animalia_Chordata_Aves_Trogoniformes...        1
#
#            Rights_holder                       Date  Latitude  Longitude  ...  \
# 8854           rguinness  2019-04-22 10:29:00+00:00 -15.78316   34.99626  ...
# 8859               Renju  2019-06-29 12:16:14+00:00   9.79733   76.28338  ...
# 8858        Bart Wursten  2018-01-24 09:43:00+00:00 -19.07145   16.58461  ...
# 8857  Abubakar S. Ringim  2019-03-14 06:34:00+00:00  11.09605    8.62213  ...
# 8856          wildchroma  2012-01-06 17:47:00+00:00  13.43873  -15.80738  ...
# ...                  ...                        ...       ...        ...  ...
# 5621           jonyboy20  2016-08-12 13:58:46+00:00   8.37735  -83.29238  ...
# 5620    Annika Lindqvist  2015-07-18 14:49:00+00:00  10.43535  -84.03313  ...
# 5627    sebastianlescano  2014-10-15 14:17:30+00:00 -25.58923  -54.07087  ...
# 5628         Zack Graham  2019-06-23 05:02:00+00:00   9.12571  -79.71493  ...
# 5625         freddiem121  2019-01-25 14:30:36+00:00   9.29259  -79.20554  ...
#
#                 Common_name Supercategory   Kingdom    Phylum Class  \
# 8854                 Shikra         Birds  Animalia  Chordata  Aves
# 8859                 Shikra         Birds  Animalia  Chordata  Aves
# 8858                 Shikra         Birds  Animalia  Chordata  Aves
# 8857                 Shikra         Birds  Animalia  Chordata  Aves
# 8856                 Shikra         Birds  Animalia  Chordata  Aves
# ...                     ...           ...       ...       ...   ...
# 5621  Black-throated Trogon         Birds  Animalia  Chordata  Aves
# 5620  Black-throated Trogon         Birds  Animalia  Chordata  Aves
# 5627  Black-throated Trogon         Birds  Animalia  Chordata  Aves
# 5628  Black-throated Trogon         Birds  Animalia  Chordata  Aves
# 5625  Black-throated Trogon         Birds  Animalia  Chordata  Aves
#
#                 Order        Family      Genus Specific_epithet  \
# 8854  Accipitriformes  Accipitridae  Accipiter           badius
# 8859  Accipitriformes  Accipitridae  Accipiter           badius
# 8858  Accipitriformes  Accipitridae  Accipiter           badius
# 8857  Accipitriformes  Accipitridae  Accipiter           badius
# 8856  Accipitriformes  Accipitridae  Accipiter           badius
# ...               ...           ...        ...              ...
# 5621    Trogoniformes    Trogonidae     Trogon            rufus
# 5620    Trogoniformes    Trogonidae     Trogon            rufus
# 5627    Trogoniformes    Trogonidae     Trogon            rufus
# 5628    Trogoniformes    Trogonidae     Trogon            rufus
# 5625    Trogoniformes    Trogonidae     Trogon            rufus
#
#                                          Image_dir_name
# 8854  03111_Animalia_Chordata_Aves_Accipitriformes_A...
# 8859  03111_Animalia_Chordata_Aves_Accipitriformes_A...
# 8858  03111_Animalia_Chordata_Aves_Accipitriformes_A...
# 8857  03111_Animalia_Chordata_Aves_Accipitriformes_A...
# 8856  03111_Animalia_Chordata_Aves_Accipitriformes_A...
# ...                                                 ...
# 5621  04596_Animalia_Chordata_Aves_Trogoniformes_Tro...
# 5620  04596_Animalia_Chordata_Aves_Trogoniformes_Tro...
# 5627  04596_Animalia_Chordata_Aves_Trogoniformes_Tro...
# 5628  04596_Animalia_Chordata_Aves_Trogoniformes_Tro...
# 5625  04596_Animalia_Chordata_Aves_Trogoniformes_Tro...
#
# [14860 rows x 22 columns]

# %%
df_val_ebird = pd.DataFrame(files_path_, columns=['File_name']) 
df_val_ebird['Image_dir_name'] = df_val_ebird.File_name.apply(lambda x: Path(x).parent.stem)
df_val_ebird['ML_Catalog_Number'] = df_val_ebird.File_name.apply(lambda x: Path(x).stem.split('_')[-1]).astype(np.int64)
df_val_ebird
# Out:
#                                                File_name  \
# 0      val_ebird/03111_Animalia_Chordata_Aves_Accipit...
# 1      val_ebird/03111_Animalia_Chordata_Aves_Accipit...
# 2      val_ebird/03111_Animalia_Chordata_Aves_Accipit...
# 3      val_ebird/03111_Animalia_Chordata_Aves_Accipit...
# 4      val_ebird/03111_Animalia_Chordata_Aves_Accipit...
# ...                                                  ...
# 14855  val_ebird/04596_Animalia_Chordata_Aves_Trogoni...
# 14856  val_ebird/04596_Animalia_Chordata_Aves_Trogoni...
# 14857  val_ebird/04596_Animalia_Chordata_Aves_Trogoni...
# 14858  val_ebird/04596_Animalia_Chordata_Aves_Trogoni...
# 14859  val_ebird/04596_Animalia_Chordata_Aves_Trogoni...
#
#                                           Image_dir_name  ML_Catalog_Number
# 0      03111_Animalia_Chordata_Aves_Accipitriformes_A...          204131931
# 1      03111_Animalia_Chordata_Aves_Accipitriformes_A...          204342841
# 2      03111_Animalia_Chordata_Aves_Accipitriformes_A...          204383371
# 3      03111_Animalia_Chordata_Aves_Accipitriformes_A...          204389521
# 4      03111_Animalia_Chordata_Aves_Accipitriformes_A...          204440111
# ...                                                  ...                ...
# 14855  04596_Animalia_Chordata_Aves_Trogoniformes_Tro...          204831231
# 14856  04596_Animalia_Chordata_Aves_Trogoniformes_Tro...          204831241
# 14857  04596_Animalia_Chordata_Aves_Trogoniformes_Tro...          204846361
# 14858  04596_Animalia_Chordata_Aves_Trogoniformes_Tro...          205024431
# 14859  04596_Animalia_Chordata_Aves_Trogoniformes_Tro...          205100971
#
# [14860 rows x 3 columns]

# %% [markdown]
# - merge with df_meta_iNat

# %%
col = ['Category_id', 'Order', 'Family', 'Genus', 'Name', 'Specific_epithet']
df_meta_iNat.sort_values(by=['Image_dir_name'], inplace=True)
df_val_ebird = pd.concat([df_val_ebird , 
                          df_meta_iNat[col].reset_index(drop=True) 
                         ], axis=1, )

# %%
# %%time
col = ['ML_Catalog_Number', 'Date', 'Latitude', 'Longitude', 'Elevation_(m)','Year','Month', 'Day']
df_val_ebird = df_val_ebird.merge(df_jpg100_meta[col], on='ML_Catalog_Number', how='left')

df_val_ebird
# Out:
# CPU times: user 168 ms, sys: 36.4 ms, total: 204 ms
# Wall time: 203 ms
#                                                File_name  \
# 0      val_ebird/03111_Animalia_Chordata_Aves_Accipit...
# 1      val_ebird/03111_Animalia_Chordata_Aves_Accipit...
# 2      val_ebird/03111_Animalia_Chordata_Aves_Accipit...
# 3      val_ebird/03111_Animalia_Chordata_Aves_Accipit...
# 4      val_ebird/03111_Animalia_Chordata_Aves_Accipit...
# ...                                                  ...
# 14855  val_ebird/04596_Animalia_Chordata_Aves_Trogoni...
# 14856  val_ebird/04596_Animalia_Chordata_Aves_Trogoni...
# 14857  val_ebird/04596_Animalia_Chordata_Aves_Trogoni...
# 14858  val_ebird/04596_Animalia_Chordata_Aves_Trogoni...
# 14859  val_ebird/04596_Animalia_Chordata_Aves_Trogoni...
#
#                                           Image_dir_name  ML_Catalog_Number  \
# 0      03111_Animalia_Chordata_Aves_Accipitriformes_A...          204131931
# 1      03111_Animalia_Chordata_Aves_Accipitriformes_A...          204342841
# 2      03111_Animalia_Chordata_Aves_Accipitriformes_A...          204383371
# 3      03111_Animalia_Chordata_Aves_Accipitriformes_A...          204389521
# 4      03111_Animalia_Chordata_Aves_Accipitriformes_A...          204440111
# ...                                                  ...                ...
# 14855  04596_Animalia_Chordata_Aves_Trogoniformes_Tro...          204831231
# 14856  04596_Animalia_Chordata_Aves_Trogoniformes_Tro...          204831241
# 14857  04596_Animalia_Chordata_Aves_Trogoniformes_Tro...          204846361
# 14858  04596_Animalia_Chordata_Aves_Trogoniformes_Tro...          205024431
# 14859  04596_Animalia_Chordata_Aves_Trogoniformes_Tro...          205100971
#
#        Category_id            Order        Family      Genus  \
# 0             3111  Accipitriformes  Accipitridae  Accipiter
# 1             3111  Accipitriformes  Accipitridae  Accipiter
# 2             3111  Accipitriformes  Accipitridae  Accipiter
# 3             3111  Accipitriformes  Accipitridae  Accipiter
# 4             3111  Accipitriformes  Accipitridae  Accipiter
# ...            ...              ...           ...        ...
# 14855         4596    Trogoniformes    Trogonidae     Trogon
# 14856         4596    Trogoniformes    Trogonidae     Trogon
# 14857         4596    Trogoniformes    Trogonidae     Trogon
# 14858         4596    Trogoniformes    Trogonidae     Trogon
# 14859         4596    Trogoniformes    Trogonidae     Trogon
#
#                    Name Specific_epithet        Date  Latitude  Longitude  \
# 0      Accipiter badius           badius  10/29/2015   23.2538    69.6619
# 1      Accipiter badius           badius    5/9/2012    0.1339    38.2256
# 2      Accipiter badius           badius   1/19/2012   22.7815    72.2067
# 3      Accipiter badius           badius    3/1/2019   28.5526    77.1506
# 4      Accipiter badius           badius   5/28/2011   45.0203    75.0274
# ...                 ...              ...         ...       ...        ...
# 14855      Trogon rufus            rufus   2/24/2019    8.9943   -79.5135
# 14856      Trogon rufus            rufus   2/24/2019    8.9943   -79.5135
# 14857      Trogon rufus            rufus  12/13/2011    8.6390   -83.1621
# 14858      Trogon rufus            rufus  12/13/2010    0.3732   -79.7034
# 14859      Trogon rufus            rufus   1/11/2014  -15.3709   -39.5542
#
#        Elevation_(m)    Year  Month   Day
# 0                NaN  2015.0   10.0  29.0
# 1                NaN  2012.0    5.0   9.0
# 2                NaN  2012.0    1.0  19.0
# 3                NaN  2019.0    3.0   1.0
# 4                NaN  2011.0    5.0  28.0
# ...              ...     ...    ...   ...
# 14855            NaN  2019.0    2.0  24.0
# 14856            NaN  2019.0    2.0  24.0
# 14857            NaN  2011.0   12.0  13.0
# 14858            NaN  2010.0   12.0  13.0
# 14859            NaN  2014.0    1.0  11.0
#
# [14860 rows x 16 columns]

# %%
df_val_ebird.to_csv('../../iNaturalist_2021/meta/val_ebird.csv')

# %%
df_val_ebird.File_name.values [:10]
# Out:
# array(['val_ebird/03111_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_badius/Accipiter_badius_0_204131931.jpg',
#        'val_ebird/03111_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_badius/Accipiter_badius_0_204131931.jpg',
#        'val_ebird/03111_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_badius/Accipiter_badius_0_204131931.jpg',
#        'val_ebird/03111_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_badius/Accipiter_badius_0_204131931.jpg',
#        'val_ebird/03111_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_badius/Accipiter_badius_0_204131931.jpg',
#        'val_ebird/03111_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_badius/Accipiter_badius_0_204131931.jpg',
#        'val_ebird/03111_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_badius/Accipiter_badius_0_204131931.jpg',
#        'val_ebird/03111_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_badius/Accipiter_badius_0_204131931.jpg',
#        'val_ebird/03111_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_badius/Accipiter_badius_0_204131931.jpg',
#        'val_ebird/03111_Animalia_Chordata_Aves_Accipitriformes_Accipitridae_Accipiter_badius/Accipiter_badius_0_204131931.jpg'],
#       dtype=object)
